# %%
import pandas as pd 
import pyarrow as pa
import pyarrow.parquet as pq
import os

# %%
df_taxis = pd.read_parquet('../Proyecto_final_henry/raw_data/taxis/taxis.parquet')

# %%
# Define una lista para almacenar los trimestres y el rango de meses correspondientes
trimestres = [(1, 'T1'), (4, 'T2'), (7, 'T3'), (10, 'T4')]

# Recorre cada trimestre y filtra los datos correspondientes
for mes_inicio, trimestre in trimestres:
    # Filtra el DataFrame por trimestre usando la función `dt.quarter`
    df_trimestre = df_taxis[df_taxis['tpep_pickup_datetime'].dt.month.isin(range(mes_inicio, mes_inicio + 3))]
    
    # Guarda cada segmento trimestral en un archivo `.parquet`
    nombre_archivo = f'../Proyecto_final_henry/raw_data/taxis/taxis_{trimestre}.parquet'
    df_trimestre.to_parquet(nombre_archivo, index=False)
    print(f"Archivo guardado: {nombre_archivo}")
# Out:
# Archivo guardado: ../Proyecto_final_henry/raw_data/taxis/taxis_T1.parquet
# Archivo guardado: ../Proyecto_final_henry/raw_data/taxis/taxis_T2.parquet
# Archivo guardado: ../Proyecto_final_henry/raw_data/taxis/taxis_T3.parquet
# Archivo guardado: ../Proyecto_final_henry/raw_data/taxis/taxis_T4.parquet

# %%
df1 =pd.read_parquet('../Proyecto_final_henry/raw_data/taxis/taxis_T1.parquet')
df2 =pd.read_parquet('../Proyecto_final_henry/raw_data/taxis/taxis_T2.parquet')

# %%
df3 =pd.read_parquet('../Proyecto_final_henry/raw_data/taxis/taxis_T3.parquet')
df4 =pd.read_parquet('../Proyecto_final_henry/raw_data/taxis/taxis_T4.parquet')

# %%
df1
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2009-01-01 07:07:04   2009-01-01 08:33:41              1.0
# 1               2  2009-01-01 00:02:43   2009-01-01 00:04:43              1.0
# 2               2  2009-01-01 00:02:43   2009-01-01 00:04:43              1.0
# 3               2  2009-01-01 00:06:35   2009-01-01 02:22:53              5.0
# 4               2  2009-01-01 15:33:49   2009-01-01 15:46:54              1.0
# ...           ...                  ...                   ...              ...
# 9722371         2  2024-03-31 23:21:41   2024-03-31 23:29:40              1.0
# 9722372         2  2024-03-31 23:45:17   2024-04-01 00:06:32              1.0
# 9722373         2  2024-03-31 23:29:17   2024-03-31 23:46:17              1.0
# 9722374         2  2009-01-01 00:39:32   2009-01-01 00:48:40              1.0
# 9722375         2  2009-01-01 00:27:54   2009-01-01 00:32:44              1.0
#
# ...

# %%
df2
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0